# %%
pip install googletrans==4.0.0-rc1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from googletrans import Translator

def translate_value(obj, translator):
    if isinstance(obj, str):
        try:
            return translator.translate(obj, dest='zh-tw').text
        except Exception as e:
            print(f"翻譯 '{obj}' 時發生錯誤: {e}")
            return obj  # 如果翻譯失敗，返回原始字符串
    elif isinstance(obj, dict):
        return {k: translate_value(v, translator) for k, v in obj.items()}
    else:
        return obj

def translate_json_file(filename, output_filename):
    translator = Translator()

    with open(filename, 'r', encoding='utf-8') as f:
        data = json.load(f)

    translated_data = translate_value(data, translator)

    with open(output_filename, 'w', encoding='utf-8') as f:
        json.dump(translated_data, f, ensure_ascii=False, indent=4)

# %%
translate_json_file(r'C:\Users\張駿宇\Documents\GitHub\spider\webui_zh.json', r'C:\Users\張駿宇\Documents\GitHub\spider\webui_zh_translated.json')
# Out:
# 翻譯 'Encoding' 時發生錯誤: 'Translator' object has no attribute 'raise_Exception'
# 翻譯 'UTF-8 (with BOM)' 時發生錯誤: 'Translator' object has no attribute 'raise_Exception'
# 翻譯 'Same as the Windows System Locale' 時發生錯誤: 'Translator' object has no attribute 'raise_Exception'
# 翻譯 'Specify the Number of Skipped Rows' 時發生錯誤: 'Translator' object has no attribute 'raise_Exception'
# 翻譯 'Number of Skipped Rows' 時發生錯誤: 'Translator' object has no attribute 'raise_Exception'
# 翻譯 'Create Group Job' 時發生錯誤: 'Translator' object has no attribute 'raise_Exception'
# 翻譯 'Job Name' 時發生錯誤: 'Translator' object has no attribute 'raise_Exception'
# 翻譯 'Add CSV Import Settings' 時發生錯誤: 'Translator' object has no attribute 'raise_Exception'
# 翻譯 'Edit CSV Import Settings' 時發生錯誤: 'Translator' object has no attribute 'raise_Exception'
# 翻譯 'Attributes Settings' 時發生錯誤: 'Translator' object has no attribute 'raise_Exception'
# 翻譯 'Attribute Name' 時發生錯誤: 'Translator' object has no attribute 'raise_Exception'
# ...

# %%
translate_json_file(r'C:\Users\張駿宇\Documents\GitHub\spider\spooler_zh.json', r'C:\Users\張駿宇\Documents\GitHub\spider\spooler_zh_translated.json')

# %%
translate_json_file(r'C:\Users\張駿宇\Documents\GitHub\spider\jobflow_zh.json', r'C:\Users\張駿宇\Documents\GitHub\spider\jobflow_zh_translated.json')
# Out:
# 翻譯 '' 時發生錯誤: the JSON object must be str, bytes or bytearray, not NoneType
