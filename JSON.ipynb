# %% [markdown]
# # JSON

# %%
var JSONUtils = {
    arrayToJson: function(array) {
        try {
            var jsonString = JSON.stringify(array);
            Watch.Log("Array successfully converted to JSON.", 3);
            return jsonString;
        } catch (e) {
            Watch.Log("Error converting array to JSON: " + e.message, 1);
            return null;
        }
    },

    sortJsonArray: function(jsonArray, field, ascending) {
        try {
            var sortedArray = jsonArray.sort(function(a, b) {
                var fieldA = a[field];
                var fieldB = b[field];
                if (fieldA < fieldB) {
                    return ascending ? -1 : 1;
                }
                if (fieldA > fieldB) {
                    return ascending ? 1 : -1;
                }
                return 0;
            });
            Watch.Log("JSON array sorted by field " + field + ".", 3);
            return sortedArray;
        } catch (e) {
            Watch.Log("Error sorting JSON array: " + e.message, 1);
            return null;
        }
    },

    splitJsonArrayToFile: function(jsonArray, field, filePathPrefix) {
        try {
            var groups = {};
            for (var i = 0; i < jsonArray.length; i++) {
                var item = jsonArray[i];
                var fieldValue = item[field];
                if (!groups[fieldValue]) {
                    groups[fieldValue] = [];
                }
                groups[fieldValue].push(item);
            }

            var fso = new ActiveXObject("Scripting.FileSystemObject");

            for (var key in groups) {
                if (groups.hasOwnProperty(key)) {
                    var jsonStr = JSON.stringify(groups[key], null, 2);
                    var filePath = filePathPrefix + "_" + key + ".json";
                    var file = fso.CreateTextFile(filePath, true);
                    file.Write(jsonStr);
                    file.Close();
                    Watch.Log("JSON file saved: " + filePath, 3);
                }
            }

            Watch.Log("JSON array split by field " + field + " and saved to files.", 3);
        } catch (e) {
            Watch.Log("Error splitting and saving JSON array: " + e.message, 1);
        }
    }
};

// Usage example
var array = [
    { "name": "Alice", "age": 30, "city": "New York" },
    { "name": "Bob", "age": 25, "city": "Los Angeles" },
    { "name": "Charlie", "age": 35, "city": "New York" },
    { "name": "David", "age": 30, "city": "Los Angeles" }
];

// Convert array to JSON
var jsonString = JSONUtils.arrayToJson(array);
Watch.Log("Converted JSON string: " + jsonString, 3);

// Parse JSON string back to JSON object
var jsonArray = JSON.parse(jsonString);

// Sort JSON array by 'age' field in ascending order
var sortedArray = JSONUtils.sortJsonArray(jsonArray, "age", true);
Watch.Log("Sorted JSON array: " + JSON.stringify(sortedArray, null, 2), 3);

// Split JSON array by 'city' field and save to files
JSONUtils.splitJsonArrayToFile(jsonArray, "city", "C:\\path\\to\\your\\output\\json_city");
